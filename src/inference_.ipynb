# %%
# !pip install -q tensorflow opencv-python matplotlib

# %%
import cv2
from matplotlib import pyplot as plt
import tensorflow as tf
import numpy as np

# %%
from tensorflow.keras.models import load_model
# facetracker = load_model("/content/drive/MyDrive/deep_learning_projects/FaceDetection/model/facetracker.h5")
facetracker = load_model("/content/drive/MyDrive/deep_learning_projects/FaceDetection/model/40_facetracker.h5")
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# img_path = "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240415_13_02_02_Pro.jpg"

# %%
# img_path = "/content/Screenshot (412).png"

# %%
img_path = "/content/test_image.jpg"
img_path = "/content/WIN_20240313_14_53_38_Pro.jpg"
img_path = "/content/WIN_20240415_13_00_16_Pro.jpg"
img_path = "/content/WIN_20240415_13_00_23_Pro.jpg"
img_path = "/content/WIN_20240415_13_02_02_Pro.jpg"
img_path = "/content/00000005.jpg"
img_path = "/content/00000004.jpg"
img_path = "/content/00000008.jpg"
img_path = "/content/00000011.jpg"
img_path = "/content/00000006.jpg"
img_path = "/content/00000003.jpg"

# %%
# img_path = "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240415_13_02_02_Pro.jpg"

# %%
image = cv2.imread(img_path)

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
image = cv2.resize(image, (450, 450))
plt.imshow(image),image.shape
# print(image)
# Out:
# (<matplotlib.image.AxesImage at 0x7da281d08610>, (450, 450, 3))

# %%
resized = tf.image.resize(image, (120,120))

# %%
type(resized)
# Out:
# tensorflow.python.framework.ops.EagerTensor

# %%
type(image)
# Out:
# numpy.ndarray

# %%
yhat = facetracker.predict(np.expand_dims(resized/255,0))
# Out:
# 1/1 [==============================] - 0s 159ms/step

# %%
sample_coords = yhat[1][0]

# %%
if yhat[0] > 0.5:
        # Controls the main rectangle
        cv2.rectangle(image,
                      tuple(np.multiply(sample_coords[:2], [450,450]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [450,450]).astype(int)),
                            (255,0,0), 2)
        plt.imshow(image)

# %%
.
# Out:
#   File "<ipython-input-83-a5d5b61aa8a6>", line 1
#     .
#     ^
# SyntaxError: invalid syntax

# %%
cv2.destroyAllWindows()

# %%
# final

# %%
import cv2
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# Assuming facetracker is your face detection model
# facetracker = YourFaceDetectionModel()

# List of image paths
img_paths = [
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240313_14_53_38_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240415_13_00_16_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240415_13_00_23_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240415_13_02_02_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/00000005.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/00000004.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/00000008.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/00000011.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/00000006.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/00000003.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_17_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_21_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_22_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_23_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_24_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_26_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_27_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_29_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_31_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_33_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_42_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_44_Pro.jpg",
    "/content/drive/MyDrive/deep_learning_projects/FaceDetection/test_images/WIN_20240416_11_29_47_Pro.jpg",

]



for img_path in img_paths:
    # Read the image
    image = cv2.imread(img_path)

    # Resize the image
    image = cv2.resize(image, (450, 450))

    # Resize using TensorFlow (if required)
    resized = tf.image.resize(image, (120, 120))

    # Predict using your facetracker model
    yhat = facetracker.predict(np.expand_dims(resized/255, 0))

    # Extract coordinates from the prediction
    sample_coords = yhat[1][0]

    # Draw rectangle if face is detected
    if yhat[0] > 0.5:
        cv2.rectangle(image,
                      tuple(np.multiply(sample_coords[:2], [450,450]).astype(int)),
                      tuple(np.multiply(sample_coords[2:], [450,450]).astype(int)),
                      (255,0,0), 2)

    # Display the image with the result
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.title(f"Image: {img_path.split('/')[-1]}")
    plt.axis('off')
    plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.
